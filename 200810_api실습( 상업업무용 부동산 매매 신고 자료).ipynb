# %%
aa='http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcNrgTrade?serviceKey=s1JerABCGMtqqLUB0r7byT8n7uzwvD9lPsxSfKp9ID5seIFNMkOQzIsACpahzhcUznSQXlirur4Ivp38W2Zd3Q%3D%3D&LAWD_CD=11110&DEAL_YMD=201512&'
print(aa)
# Out:
# http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcNrgTrade?serviceKey=s1JerABCGMtqqLUB0r7byT8n7uzwvD9lPsxSfKp9ID5seIFNMkOQzIsACpahzhcUznSQXlirur4Ivp38W2Zd3Q%3D%3D&LAWD_CD=11110&DEAL_YMD=201512&

# %% [markdown]
# #### url 불러오는 방법 2.

# %%
my2='s1JerABCGMtqqLUB0r7byT8n7uzwvD9lPsxSfKp9ID5seIFNMkOQzIsACpahzhcUznSQXlirur4Ivp38W2Zd3Q%3D%3D'

# %%
LAWD_CD='11110'
DEAL_YMD='201512'
base_url='http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcNrgTrade?'
params='serviceKey=%s&LAWD_CD=%s&DEAL_YMD=%s'%(my,LAWD_CD,DEAL_YMD)
url3='&type=json'
url=base_url+params+url3
print(url)
# Out:
# http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcNrgTrade?serviceKey=u2F20yN80DDP%2BtJVa6M7J0H6Cmzr10AKBgVTKS2e8U28Cxs0iAv7xmUcL7B0vLgMG1mCTcCsMIMY5JougOHTXg%3D%3D&LAWD_CD=11110&DEAL_YMD=201512&type=json

# %%
LAWD_CD='11110'
DEAL_YMD='201512'
base_url='http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcNrgTrade?'
params='serviceKey=%s&LAWD_CD=%s&DEAL_YMD=%s'%(my2,LAWD_CD,DEAL_YMD)
url3='&type=json'
url=base_url+params+url3
print(url)
# Out:
# http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcNrgTrade?serviceKey=s1JerABCGMtqqLUB0r7byT8n7uzwvD9lPsxSfKp9ID5seIFNMkOQzIsACpahzhcUznSQXlirur4Ivp38W2Zd3Q%3D%3D&LAWD_CD=11110&DEAL_YMD=201512&type=json

# %% [markdown]
# #### url두개의 차이점 비교하기

# %%
aa1==url
# Out:
# False

# %%
aa1='http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcNrgTrade?serviceKey=s1JerABCGMtqqLUB0r7byT8n7uzwvD9lPsxSfKp9ID5seIFNMkOQzIsACpahzhcUznSQXlirur4Ivp38W2Zd3Q%3D%3D&LAWD_CD=11110&DEAL_YMD=201512&s'
url='http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcNrgTrade?serviceKey=s1JerABCGMtqqLUB0r7byT8n7uzwvD9lPsxSfKp9ID5seIFNMkOQzIsACpahzhcUznSQXlirur4Ivp38W2Zd3Q%3D%3D&LAWD_CD=11110&DEAL_YMD=201512&type=json'
for i, check in enumerate(aa1):
    if check != url[i]:
        print('find!!!=', i)
# Out:
# find!!!= 235

# %%
for i, check in enumerate(aa1):
    if check != url[i]:
        print('find!!!=', i)
        print('aa=', aa1[i-5:i+5])
        print('url=', aa1[i-5:i+5])
# Out:
# find!!!= 235
# aa= 1512&s
# url= 1512&s

# %% [markdown]
# #### url 불러오는 방법 3.   (decode 하는 이유_ url을 복사하면 이상한 문자로 변하기 때문.)

# %%
import requests
LAWD_CD='11110'
DEAL_YMD='201512'
base_url='http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcNrgTrade?'
my2_decode= requests.utils.unquote(my2)
base_url='http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcNrgTrade?'
req_params= {'serviceKey': my2_decode, 'LAWD_CD':LAWD_CD, 'DEAL_YMD':DEAL_YMD, 'type':'json' }
r= requests.get(base_url, params=req_params)
print(r.url)
# Out:
# http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcNrgTrade?serviceKey=s1JerABCGMtqqLUB0r7byT8n7uzwvD9lPsxSfKp9ID5seIFNMkOQzIsACpahzhcUznSQXlirur4Ivp38W2Zd3Q%3D%3D&LAWD_CD=11110&DEAL_YMD=201512&type=json

# %% [markdown]
# #### 만든 url의 데이터를 읽어오기

# %%
import urllib.request
res= urllib.request.urlopen(url);res

# %%
json_str= res.read();json_str

# %% [markdown]
# #### 깨진 한글 불러오기_ xml형태이고, 아주 큰 문자열 형태

# %%
import urllib.request
res= urllib.request.urlopen(url);res
xml_str = res.read().decode('utf-8');xml_str
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><거래금액>120,000</거래금액><건물면적>395</건물면적><건물주용도>제2종근린생활</건물주용도><건축년도>2001</건축년도><년>2015</년><대지면적>160.64</대지면적><법정동> 효자동</법정동><시군구>종로구</시군구><용도지역>제2종일반주거</용도지역><월>12</월><유형>일반</유형><일>31</일><지역코드>11110</지역코드></item><item><거래금액>483,000</거래금액><건물면적>937</건물면적><건물주용도>제2종근린생활</건물주용도><건축년도>1990</건축년도><년>2015</년><대지면적>503.5</대지면적><법정동> 체부동</법정동><시군구>종로구</시군구><용도지역>제2종일반주거</용도지역><월>12</월><유형>일반</유형><일>15</일><지역코드>11110</지역코드></item><item><거래금액>22,000</거래금액><건물면적>31</건물면적><건물주용도>판매</건물주용도><건축년도>2007</건축년도><년>2015</년><대지면적> </대지면적><법정동> 종로1가</법정동><시군구>종로구</시군구><용도지역>일반상업</용도지역><월>12</월><유형>집합</유형><일>10</일><지역코드>11110</지역코드><층>-1</층></item><item><거래금액>158,000</거래금액><건물면적>276</건물면적><건물주용도>숙박</건물주용도><건축년도>1959</건축년도><년>2015</년><대지면적>72.8</대지면적><법정동> 와룡동</법정동><시군구>종로구</시군구><용도지역>일반상업</용도지역><월>12</월><유형>일반</유형><일>8</일><지역코드>11110</지역코드></ite
# ...

# %% [markdown]
# #### xml형식을 json형태로 바꾸는 작업

# %%
import xmltodict         # xml을 dict 형태로 변환
import json
json_str = json.dumps(xmltodict.parse(xml_str), indent=4, ensure_ascii=False)   
json_object = json.loads(json_str)

# %%
type(json_object)
# Out:
# dict

# %% [markdown]
# #### pandas 로 불러오기

# %%
import pandas as pd
from pandas.io.json import json_normalize

# %%
json_object.keys()
# Out:
# dict_keys(['response'])

# %%
json_object['response']['body']['items']['item']
# Out:
# [{'거래금액': '120,000',
#   '건물면적': '395',
#   '건물주용도': '제2종근린생활',
#   '건축년도': '2001',
#   '년': '2015',
#   '대지면적': '160.64',
#   '법정동': '효자동',
#   '시군구': '종로구',
#   '용도지역': '제2종일반주거',
#   '월': '12',
#   '유형': '일반',
#   '일': '31',
#   '지역코드': '11110'},
#  {'거래금액': '483,000',
#   '건물면적': '937',
#   '건물주용도': '제2종근린생활',
#   '건축년도': '1990',
#   '년': '2015',
#   '대지면적': '503.5',
#   '법정동': '체부동',
#   '시군구': '종로구',
#   '용도지역': '제2종일반주거',
#   '월': '12',
#   '유형': '일반',
#   '일': '15',
#   '지역코드': '11110'},
#  {'거래금액': '22,000',
#   '건물면적': '31',
#   '건물주용도': '판매',
#   '건축년도': '2007',
#   '년': '2015',
#   '대지면적': None,
#   '법정동': '종로1가',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '12',
#   '유형': '집합',
#   '일': '10',
#   '지역코드': '11110',
#   '층': '-1'},
#  {'거래금액': '158,000',
#   '건물면적': '276',
#   '건물주용도': '숙박',
#   '건축년도': '1959',
#   '년': '2015',
#   '대지면적': '72.8',
#   '법정동': '와룡동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '12',
#   '유형': '일반',
#   '일': '8',
#   '지역코드': '11110'},
# ...

# %%
df=json_normalize(json_object['response']['body']['items']['item'])
df.head(3)
# Out:
# <ipython-input-106-a6aa3e682f9f>:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df=json_normalize(json_object['response']['body']['items']['item'])
#       거래금액 건물면적    건물주용도  건축년도     년    대지면적   법정동  시군구     용도지역   월  유형   일   지역코드    층
# 0  120,000  395  제2종근린생활  2001  2015  160.64   효자동  종로구  제2종일반주거  12  일반  31  11110  NaN
# 1  483,000  937  제2종근린생활  1990  2015   503.5   체부동  종로구  제2종일반주거  12  일반  15  11110  NaN
# 2   22,000   31       판매  2007  2015    None  종로1가  종로구     일반상업  12  집합  10  11110   -1

# %% [markdown]
# ##### json= 1. 데이터를 전달하기 위해 만든 구조화된 텍스트 형식
# #####            2. 하나의 데이터 집합을 객체(object) 객체의 구성은 쌍의 집합 ex. {'abs' :'adk......}
# ##### json viewer에서 볼 수 있음.

# %%
import json

# %%
dir(json)
# Out:
# ['JSONDecodeError',
#  'JSONDecoder',
#  'JSONEncoder',
#  '__all__',
#  '__author__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_default_decoder',
#  '_default_encoder',
#  'codecs',
#  'decoder',
#  'detect_encoding',
#  'dump',
#  'dumps',
#  'encoder',
#  'load',
#  'loads',
#  'scanner']

# %% [markdown]
# #### json 데이터 만들어보기

# %%
data=['foo',{'bar':('baz',None,1,0,2)}]
data
# Out:
# ['foo', {'bar': ('baz', None, 1, 0, 2)}]

# %%
type(data)
# Out:
# list

# %% [markdown]
# #### 파이썬 데이터를 json 데이터로 변환하기(json.dumps()

# %%
json.dumps(data)
# Out:
# '["foo", {"bar": ["baz", null, 1, 0, 2]}]'

# %%
json.dumps({'c':0,'d':1}, sort_keys=True)
# Out:
# '{"c": 0, "d": 1}'

# %%
import json
dict_data={'이름':'김아무개','나이':29,'거주지':'서울','신체정보':{'키':164,'몸무게':55}, '취미':['파이썬','데이터덕후']}
type(dict_data)
# Out:
# dict

# %%
dict_data
# Out:
# {'이름': '김아무개',
#  '나이': 29,
#  '거주지': '서울',
#  '신체정보': {'키': 164, '몸무게': 55},
#  '취미': ['파이썬', '데이터덕후']}

# %%
json_data= json.dumps(dict_data)
type(json_data)
# Out:
# str

# %%
print(json_data)
# Out:
# {"\uc774\ub984": "\uae40\uc544\ubb34\uac1c", "\ub098\uc774": 29, "\uac70\uc8fc\uc9c0": "\uc11c\uc6b8", "\uc2e0\uccb4\uc815\ubcf4": {"\ud0a4": 164, "\ubab8\ubb34\uac8c": 55}, "\ucde8\ubbf8": ["\ud30c\uc774\uc36c", "\ub370\uc774\ud130\ub355\ud6c4"]}

# %%
json_data= json.dumps(dict_data, indent=3, sort_keys=True, ensure_ascii=False)
print(json_data)
# Out:
# {
#    "거주지": "서울",
#    "나이": 29,
#    "신체정보": {
#       "몸무게": 55,
#       "키": 164
#    },
#    "이름": "김아무개",
#    "취미": [
#       "파이썬",
#       "데이터덕후"
#    ]
# }
